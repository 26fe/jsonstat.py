# %% [markdown]
# ## Notebook: using jsonstat.py to explore Istat data
# This Jupyter notebook shows how to use [jsonstat.py](http://github.com/26fe/jsonstat.py) python library to explore Istat data.
# [Istat](http://www.istat.it/en/about-istat) is Italian National Institute of Statistics. It publishs a rest api for querying italian statistics.

# %%
from __future__ import print_function
import os
import pandas as ps
import jsonstat
import jsonstat.istat as istat

# %% [markdown]
# Setting a cache dir to store json files download by Istat api

# %%
cache_dir = os.path.abspath(os.path.join("..", "tmp", "istat_cached"))
if not os.path.exists(cache_dir):
    os.makedirs(cache_dir)
print("cache_dir is '{}'".format(cache_dir))
# Out:
# cache_dir is '/Users/26fe_nas/prj.python/jsonstat.py/tmp/istat_cached'

# %% [markdown]
# List all istat areas

# %%
i = istat.Istat(cache_dir)
for istat_area in i.areas():
    print(istat_area)
# Out:
# CEN:2011 Population and housing census
# ENT:Enterprises
# ENV:Environment and Energy
# POP:Population and Households
# HOU:Households Economic Conditions and Disparities
# HEA:Health statistics
# WEL:Social Security and Welfare
# EDU:Education and training
# COM:Communication, culture and leisure
# JUS:Justice and Security
# OPI:Citizens' opinions and satisfaction with life
# SOC:Social participation
# ACC:National Accounts
# AGR:Agriculture
# IND:Industry and Construction
# SER:Services
# PUB:Public Administrations and Private Institutions
# EXT:External Trade and Internationalisation
# PRI:Prices
# LAB:Labour

# %% [markdown]
# List all datasets contained into area `Prices`

# %%
istat_area_name = 'Prices'
istat_area = i.area(istat_area_name)

for istat_dataset in istat_area.datasets():
    print(u"{}({}):{}".format(istat_dataset.cod(), istat_dataset.nrdim(), istat_dataset.name()))
# Out:
# DCSP_FOI2(5):FOI  Annual average  until 2010
# DCSP_FOI3(4):FOI  Weights until 2010
# DCSP_FOI1(5):FOI  Monthly data until 2010
# DCSP_NICDUE(5):NIC  Annual average until 2010
# DCSP_NICTREB2010(4):NIC  Weights from 2011 onwards
# DCSP_FOI3B2010(4):FOI  Weights from 2011 onwards
# DCSP_IPAB(5):House price index
# DCSP_NICUNOBB2010(5):NIC  Monthly data from 2011 onwards
# DCSC_PREZPRODSERV_1(5):Services producer prices index
# DCSC_FABBRESID_1(5):Construction costs index - monthly data
# DCSP_NICTRE(4):NIC  Weights  until 2010
# DCSP_NICUNOB(5):NIC  Monthly data until 2010
# DCSP_IPCA1(5):HICP  Monthly data from 2001 onwards (base 2005=100)
# DCSP_IPCA2(5):HICP  Annual average from 2001 onwards (base 2005=100)
# DCSP_IPCA3(4):HICP  Weights from 2001 onwards
# DCSP_IPCATC2(5):HICP at constant tax rates  Annual average from 2002 onwards (base 2005=100)
# DCSP_IPCATC1(5):HICP at constant tax rates  Monthly data from 2002 onwards (base 2005=100)
# DCSP_FOI1B2010(5):FOI  Monthly data from 2011 onwards
# DCSP_NICDUEB2010(5):NIC  Annual average from 2011 onwards
# DCSC_PREZZPIND_1(6):Producer price index for industrial products - monthly data
# DCSP_FOI2B2010(5):FOI  Annual average from 2011  onwards

# %% [markdown]
# List all dimension for dataset `DCSP_IPAB` (House price index)

# %%
istat_dataset_name = 'DCSP_IPAB'
istat_dataset = istat_area.dataset(istat_dataset_name)
istat_dataset.info_dimensions()
# Out:
# dim 0 'Territory' (1:'Italy')
# dim 1 'Index type' (18:'house price index (base 2010=100) - quarterly data', 19:'house price index (base 2010=100) - annual average', 20:'house price index (base 2010=100) - weights')
# dim 2 'Measure' (8:'annual average rate of change', 4:'index number', 22:'not applicable', 6:'percentage changes on the previous period', 7:'percentage changes on the same period of the previous year')
# dim 3 'Purchases of dwellings' (4:'H1 - all items', 5:'H11 - new dwellings', 6:'H12 - existing dwellings')
# dim 4 'Time and frequency' (2178:'Q3-2014', 2182:'Q4-2014', 2186:'2015', 2188:'Q1-2015', 2192:'Q2-2015', 2197:'Q3-2015', 2091:'2010', 2093:'Q1-2010', 2097:'Q2-2010', 2102:'Q3-2010', 2106:'Q4-2010', 2110:'2011', 2112:'Q1-2011', 2116:'Q2-2011', 2121:'Q3-2011', 2125:'Q4-2011', 2129:'2012', 2131:'Q1-2012', 2135:'Q2-2012', 2140:'Q3-2012', 2144:'Q4-2012', 2148:'2013', 2150:'Q1-2013', 2154:'Q2-2013', 2159:'Q3-2013', 2163:'Q4-2013', 2167:'2014', 2169:'Q1-2014', 2173:'Q2-2014')

# %% [markdown]
# Extract data from dataset `DCSP_IPAB` with dimension "1,18,0,0,0" where the first dimension is Territory, etc. Below is the mapping:
# - Territory 1 -> Italy
# - Type 18 -> 'house price index (base 2010=100) - quarterly data'
# - Measure 0 -> ALL
# - Purchase of dwelling 0 -> ALL
# - Time and frequency 0 -> ALL

# %%
# TODO: passing dictionary to getvalues
spec = { 
    "Territory": 1, "Index type": 18, 
    # "Measure": 0, # "Purchases of dwelling": 0, # "Time and frequency": 0
}
# convert istat dataset into jsonstat collection and print some info
collection = istat_dataset.getvalues(spec)
collection.info()
# Out:
# 0: dataset 'IDMISURA1*IDTYPPURCH*IDTIME'

# %% [markdown]
# Print some info of one dataset contained into the above jsonstat collection

# %%
jsonstat_dataset = collection.dataset('IDMISURA1*IDTYPPURCH*IDTIME')
jsonstat_dataset.info()
# Out:
# name:   'IDMISURA1*IDTYPPURCH*IDTIME'
# label:  'House price index  by Measure, Purchases of dwellings and Time and frequency - Italy - house price index (base 2010=100) - quarterly data'
# size: 207
# 3 dimensions:
#   0: dim id/name: 'IDMISURA1' size: '3' role: 'None'
#   1: dim id/name: 'IDTYPPURCH' size: '3' role: 'None'
#   2: dim id/name: 'IDTIME' size: '23' role: 'None'

# %%
jsonstat_dataset.dimension('IDMISURA1')
# Out:
# index
#   pos    idx  label
#     0      4 index number
#     1      6 percentage changes on the previous period
#     2      7 percentage changes on the same period of the previous year

# %%
jsonstat_dataset.dimension('IDTYPPURCH')
# Out:
# index
#   pos    idx  label
#     0      4 H1 - all items
#     1      5 H11 - new dwellings
#     2      6 H12 - existing dwellings

# %%
jsonstat_dataset.dimension('IDTIME')
# Out:
# index
#   pos    idx  label
#     0   2093 Q1-2010
#     1   2097 Q2-2010
#     2   2102 Q3-2010
#     3   2106 Q4-2010
#     4   2112 Q1-2011
#     5   2116 Q2-2011
#     6   2121 Q3-2011
#     7   2125 Q4-2011
#     8   2131 Q1-2012
#     9   2135 Q2-2012
#    10   2140 Q3-2012
#    11   2144 Q4-2012
#    12   2150 Q1-2013
#    13   2154 Q2-2013
#    14   2159 Q3-2013
#    15   2163 Q4-2013
#    16   2169 Q1-2014
#    17   2173 Q2-2014
#    18   2178 Q3-2014
#    19   2182 Q4-2014
#    20   2188 Q1-2015
#    21   2192 Q2-2015
#    22   2197 Q3-2015

# %%
json_stat_data = istat_dataset.getvalues("1,18,4,4,0")
json_stat_data
# Out:
# 0: dataset 'IDTIME'

# %%
jsonstat_dataset.to_table()
# Out:
# [[u'Measure', u'Purchases of dwellings', u'Time and frequency', u'Value'],
#  [u'index number', u'H1 - all items', u'Q1-2010', 99.5],
#  [u'percentage changes on the previous period',
#   u'H1 - all items',
#   u'Q1-2010',
#   None],
#  [u'percentage changes on the same period of the previous year',
#   u'H1 - all items',
#   u'Q1-2010',
#   None],
#  [u'index number', u'H11 - new dwellings', u'Q1-2010', 99.1],
#  [u'percentage changes on the previous period',
#   u'H11 - new dwellings',
#   u'Q1-2010',
#   None],
#  [u'percentage changes on the same period of the previous year',
#   u'H11 - new dwellings',
#   u'Q1-2010',
#   None],
#  [u'index number', u'H12 - existing dwellings', u'Q1-2010', 99.7],
#  [u'percentage changes on the previous period',
#   u'H12 - existing dwellings',
#   u'Q1-2010',
#   None],
#  [u'percentage changes on the same period of the previous year',
#   u'H12 - existing dwellings',
#   u'Q1-2010',
#   None],
#  [u'index number', u'H1 - all items', u'Q2-2010', 100],
#  [u'percentage changes on the previous period',
#   u'H1 - all items',
#   u'Q2-2010',
#   0.5],
#  [u'percentage changes on the same period of the previous year',
#   u'H1 - all items',
#   u'Q2-2010',
#   None],
#  [u'index number', u'H11 - new dwellings', u'Q2-2010', 99.5],
#  [u'percentage changes on the previous period',
#   u'H11 - new dwellings',
#   u'Q2-2010',
#   0.4],
#  [u'percentage changes on the same period of the previous year',
#   u'H11 - new dwellings',
#   u'Q2-2010',
#   None],
#  [u'index number', u'H12 - existing dwellings', u'Q2-2010', 100.2],
#  [u'percentage changes on the previous period',
#   u'H12 - existing dwellings',
#   u'Q2-2010',
#   0.5],
#  [u'percentage changes on the same period of the previous year',
#   u'H12 - existing dwellings',
#   u'Q2-2010',
#   None],
#  [u'index number', u'H1 - all items', u'Q3-2010', 100.3],
#  [u'percentage changes on the previous period',
#   u'H1 - all items',
#   u'Q3-2010',
#   0.3],
#  [u'percentage changes on the same period of the previous year',
#   u'H1 - all items',
#   u'Q3-2010',
#   None],
#  [u'index number', u'H11 - new dwellings', u'Q3-2010', 100.3],
#  [u'percentage changes on the previous period',
#   u'H11 - new dwellings',
#   u'Q3-2010',
#   0.8],
#  [u'percentage changes on the same period of the previous year',
#   u'H11 - new dwellings',
#   u'Q3-2010',
#   None],
#  [u'index number', u'H12 - existing dwellings', u'Q3-2010', 100.3],
#  [u'percentage changes on the previous period',
#   u'H12 - existing dwellings',
#   u'Q3-2010',
#   0.1],
#  [u'percentage changes on the same period of the previous year',
#   u'H12 - existing dwellings',
#   u'Q3-2010',
#   None],
#  [u'index number', u'H1 - all items', u'Q4-2010', 100.2],
#  [u'percentage changes on the previous period',
#   u'H1 - all items',
#   u'Q4-2010',
#   -0.1],
#  [u'percentage changes on the same period of the previous year',
#   u'H1 - all items',
#   u'Q4-2010',
#   None],
#  [u'index number', u'H11 - new dwellings', u'Q4-2010', 101.1],
#  [u'percentage changes on the previous period',
#   u'H11 - new dwellings',
#   u'Q4-2010',
#   0.8],
#  [u'percentage changes on the same period of the previous year',
#   u'H11 - new dwellings',
#   u'Q4-2010',
#   None],
#  [u'index number', u'H12 - existing dwellings', u'Q4-2010', 99.7],
#  [u'percentage changes on the previous period',
#   u'H12 - existing dwellings',
#   u'Q4-2010',
#   -0.6],
#  [u'percentage changes on the same period of the previous year',
#   u'H12 - existing dwellings',
#   u'Q4-2010',
#   None],
#  [u'index number', u'H1 - all items', u'Q1-2011', 100.1],
#  [u'percentage changes on the previous period',
#   u'H1 - all items',
#   u'Q1-2011',
#   -0.1],
#  [u'percentage changes on the same period of the previous year',
#   u'H1 - all items',
#   u'Q1-2011',
#   0.6],
#  [u'index number', u'H11 - new dwellings', u'Q1-2011', 101.4],
#  [u'percentage changes on the previous period',
#   u'H11 - new dwellings',
#   u'Q1-2011',
#   0.3],
#  [u'percentage changes on the same period of the previous year',
#   u'H11 - new dwellings',
#   u'Q1-2011',
#   2.3],
#  [u'index number', u'H12 - existing dwellings', u'Q1-2011', 99.4],
#  [u'percentage changes on the previous period',
#   u'H12 - existing dwellings',
#   u'Q1-2011',
#   -0.3],
#  [u'percentage changes on the same period of the previous year',
#   u'H12 - existing dwellings',
#   u'Q1-2011',
#   -0.3],
#  [u'index number', u'H1 - all items', u'Q2-2011', 101.2],
#  [u'percentage changes on the previous period',
#   u'H1 - all items',
#   u'Q2-2011',
#   1.1],
#  [u'percentage changes on the same period of the previous year',
#   u'H1 - all items',
#   u'Q2-2011',
#   1.2],
#  [u'index number', u'H11 - new dwellings', u'Q2-2011', 102.5],
#  [u'percentage changes on the previous period',
#   u'H11 - new dwellings',
#   u'Q2-2011',
#   1.1],
#  [u'percentage changes on the same period of the previous year',
#   u'H11 - new dwellings',
#   u'Q2-2011',
#   3],
#  [u'index number', u'H12 - existing dwellings', u'Q2-2011', 100.5],
#  [u'percentage changes on the previous period',
#   u'H12 - existing dwellings',
#   u'Q2-2011',
#   1.1],
#  [u'percentage changes on the same period of the previous year',
#   u'H12 - existing dwellings',
#   u'Q2-2011',
#   0.3],
#  [u'index number', u'H1 - all items', u'Q3-2011', 101.2],
#  [u'percentage changes on the previous period',
#   u'H1 - all items',
#   u'Q3-2011',
#   None],
#  [u'percentage changes on the same period of the previous year',
#   u'H1 - all items',
#   u'Q3-2011',
#   0.9],
#  [u'index number', u'H11 - new dwellings', u'Q3-2011', 103.2],
#  [u'percentage changes on the previous period',
#   u'H11 - new dwellings',
#   u'Q3-2011',
#   0.7],
#  [u'percentage changes on the same period of the previous year',
#   u'H11 - new dwellings',
#   u'Q3-2011',
#   2.9],
#  [u'index number', u'H12 - existing dwellings', u'Q3-2011', 100.3],
#  [u'percentage changes on the previous period',
#   u'H12 - existing dwellings',
#   u'Q3-2011',
#   -0.2],
#  [u'percentage changes on the same period of the previous year',
#   u'H12 - existing dwellings',
#   u'Q3-2011',
#   None],
#  [u'index number', u'H1 - all items', u'Q4-2011', 100.5],
#  [u'percentage changes on the previous period',
#   u'H1 - all items',
#   u'Q4-2011',
#   -0.7],
#  [u'percentage changes on the same period of the previous year',
#   u'H1 - all items',
#   u'Q4-2011',
#   0.3],
#  [u'index number', u'H11 - new dwellings', u'Q4-2011', 103.6],
#  [u'percentage changes on the previous period',
#   u'H11 - new dwellings',
#   u'Q4-2011',
#   0.4],
#  [u'percentage changes on the same period of the previous year',
#   u'H11 - new dwellings',
#   u'Q4-2011',
#   2.5],
#  [u'index number', u'H12 - existing dwellings', u'Q4-2011', 99],
#  [u'percentage changes on the previous period',
#   u'H12 - existing dwellings',
#   u'Q4-2011',
#   -1.3],
#  [u'percentage changes on the same period of the previous year',
#   u'H12 - existing dwellings',
#   u'Q4-2011',
#   -0.7],
#  [u'index number', u'H1 - all items', u'Q1-2012', 99.9],
#  [u'percentage changes on the previous period',
#   u'H1 - all items',
#   u'Q1-2012',
#   -0.6],
#  [u'percentage changes on the same period of the previous year',
#   u'H1 - all items',
#   u'Q1-2012',
#   -0.2],
#  [u'index number', u'H11 - new dwellings', u'Q1-2012', 104.9],
#  [u'percentage changes on the previous period',
#   u'H11 - new dwellings',
#   u'Q1-2012',
#   1.3],
#  [u'percentage changes on the same period of the previous year',
#   u'H11 - new dwellings',
#   u'Q1-2012',
#   3.5],
#  [u'index number', u'H12 - existing dwellings', u'Q1-2012', 97.7],
#  [u'percentage changes on the previous period',
#   u'H12 - existing dwellings',
#   u'Q1-2012',
#   -1.3],
#  [u'percentage changes on the same period of the previous year',
#   u'H12 - existing dwellings',
#   u'Q1-2012',
#   -1.7],
#  [u'index number', u'H1 - all items', u'Q2-2012', 99.1],
#  [u'percentage changes on the previous period',
#   u'H1 - all items',
#   u'Q2-2012',
#   -0.8],
#  [u'percentage changes on the same period of the previous year',
#   u'H1 - all items',
#   u'Q2-2012',
#   -2.1],
#  [u'index number', u'H11 - new dwellings', u'Q2-2012', 105.4],
#  [u'percentage changes on the previous period',
#   u'H11 - new dwellings',
#   u'Q2-2012',
#   0.5],
#  [u'percentage changes on the same period of the previous year',
#   u'H11 - new dwellings',
#   u'Q2-2012',
#   2.8],
#  [u'index number', u'H12 - existing dwellings', u'Q2-2012', 96.4],
#  [u'percentage changes on the previous period',
#   u'H12 - existing dwellings',
#   u'Q2-2012',
#   -1.3],
#  [u'percentage changes on the same period of the previous year',
#   u'H12 - existing dwellings',
#   u'Q2-2012',
#   -4.1],
#  [u'index number', u'H1 - all items', u'Q3-2012', 97.4],
#  [u'percentage changes on the previous period',
#   u'H1 - all items',
#   u'Q3-2012',
#   -1.7],
#  [u'percentage changes on the same period of the previous year',
#   u'H1 - all items',
#   u'Q3-2012',
#   -3.8],
#  [u'index number', u'H11 - new dwellings', u'Q3-2012', 104.7],
#  [u'percentage changes on the previous period',
#   u'H11 - new dwellings',
#   u'Q3-2012',
#   -0.7],
#  [u'percentage changes on the same period of the previous year',
#   u'H11 - new dwellings',
#   u'Q3-2012',
#   1.5],
#  [u'index number', u'H12 - existing dwellings', u'Q3-2012', 94.3],
#  [u'percentage changes on the previous period',
#   u'H12 - existing dwellings',
#   u'Q3-2012',
#   -2.2],
#  [u'percentage changes on the same period of the previous year',
#   u'H12 - existing dwellings',
#   u'Q3-2012',
#   -6],
#  [u'index number', u'H1 - all items', u'Q4-2012', 95.3],
#  [u'percentage changes on the previous period',
#   u'H1 - all items',
#   u'Q4-2012',
#   -2.2],
#  [u'percentage changes on the same period of the previous year',
#   u'H1 - all items',
#   u'Q4-2012',
#   -5.2],
#  [u'index number', u'H11 - new dwellings', u'Q4-2012', 104.7],
#  [u'percentage changes on the previous period',
#   u'H11 - new dwellings',
#   u'Q4-2012',
#   None],
#  [u'percentage changes on the same period of the previous year',
#   u'H11 - new dwellings',
#   u'Q4-2012',
#   1.1],
#  [u'index number', u'H12 - existing dwellings', u'Q4-2012', 91.2],
#  [u'percentage changes on the previous period',
#   u'H12 - existing dwellings',
#   u'Q4-2012',
#   -3.3],
#  [u'percentage changes on the same period of the previous year',
#   u'H12 - existing dwellings',
#   u'Q4-2012',
#   -7.9],
#  [u'index number', u'H1 - all items', u'Q1-2013', 93.9],
#  [u'percentage changes on the previous period',
#   u'H1 - all items',
#   u'Q1-2013',
#   -1.5],
#  [u'percentage changes on the same period of the previous year',
#   u'H1 - all items',
#   u'Q1-2013',
#   -6],
#  [u'index number', u'H11 - new dwellings', u'Q1-2013', 103.5],
#  [u'percentage changes on the previous period',
#   u'H11 - new dwellings',
#   u'Q1-2013',
#   -1.1],
#  [u'percentage changes on the same period of the previous year',
#   u'H11 - new dwellings',
#   u'Q1-2013',
#   -1.3],
#  [u'index number', u'H12 - existing dwellings', u'Q1-2013', 89.8],
#  [u'percentage changes on the previous period',
#   u'H12 - existing dwellings',
#   u'Q1-2013',
#   -1.5],
#  [u'percentage changes on the same period of the previous year',
#   u'H12 - existing dwellings',
#   u'Q1-2013',
#   -8.1],
#  [u'index number', u'H1 - all items', u'Q2-2013', 93.3],
#  [u'percentage changes on the previous period',
#   u'H1 - all items',
#   u'Q2-2013',
#   -0.6],
#  [u'percentage changes on the same period of the previous year',
#   u'H1 - all items',
#   u'Q2-2013',
#   -5.9],
#  [u'index number', u'H11 - new dwellings', u'Q2-2013', 103.1],
#  [u'percentage changes on the previous period',
#   u'H11 - new dwellings',
#   u'Q2-2013',
#   -0.4],
#  [u'percentage changes on the same period of the previous year',
#   u'H11 - new dwellings',
#   u'Q2-2013',
#   -2.2],
#  [u'index number', u'H12 - existing dwellings', u'Q2-2013', 89.1],
#  [u'percentage changes on the previous period',
#   u'H12 - existing dwellings',
#   u'Q2-2013',
#   -0.8],
#  [u'percentage changes on the same period of the previous year',
#   u'H12 - existing dwellings',
#   u'Q2-2013',
#   -7.6],
#  [u'index number', u'H1 - all items', u'Q3-2013', 91.9],
#  [u'percentage changes on the previous period',
#   u'H1 - all items',
#   u'Q3-2013',
#   -1.5],
#  [u'percentage changes on the same period of the previous year',
#   u'H1 - all items',
#   u'Q3-2013',
#   -5.6],
#  [u'index number', u'H11 - new dwellings', u'Q3-2013', 102.1],
#  [u'percentage changes on the previous period',
#   u'H11 - new dwellings',
#   u'Q3-2013',
#   -1],
#  [u'percentage changes on the same period of the previous year',
#   u'H11 - new dwellings',
#   u'Q3-2013',
#   -2.5],
#  [u'index number', u'H12 - existing dwellings', u'Q3-2013', 87.5],
#  [u'percentage changes on the previous period',
#   u'H12 - existing dwellings',
#   u'Q3-2013',
#   -1.8],
#  [u'percentage changes on the same period of the previous year',
#   u'H12 - existing dwellings',
#   u'Q3-2013',
#   -7.2],
#  [u'index number', u'H1 - all items', u'Q4-2013', 90.2],
#  [u'percentage changes on the previous period',
#   u'H1 - all items',
#   u'Q4-2013',
#   -1.8],
#  [u'percentage changes on the same period of the previous year',
#   u'H1 - all items',
#   u'Q4-2013',
#   -5.4],
#  [u'index number', u'H11 - new dwellings', u'Q4-2013', 100.9],
#  [u'percentage changes on the previous period',
#   u'H11 - new dwellings',
#   u'Q4-2013',
#   -1.2],
#  [u'percentage changes on the same period of the previous year',
#   u'H11 - new dwellings',
#   u'Q4-2013',
#   -3.6],
#  [u'index number', u'H12 - existing dwellings', u'Q4-2013', 85.7],
#  [u'percentage changes on the previous period',
#   u'H12 - existing dwellings',
#   u'Q4-2013',
#   -2.1],
#  [u'percentage changes on the same period of the previous year',
#   u'H12 - existing dwellings',
#   u'Q4-2013',
#   -6],
#  [u'index number', u'H1 - all items', u'Q1-2014', 89.3],
#  [u'percentage changes on the previous period',
#   u'H1 - all items',
#   u'Q1-2014',
#   -1],
#  [u'percentage changes on the same period of the previous year',
#   u'H1 - all items',
#   u'Q1-2014',
#   -4.9],
#  [u'index number', u'H11 - new dwellings', u'Q1-2014', 100.5],
#  [u'percentage changes on the previous period',
#   u'H11 - new dwellings',
#   u'Q1-2014',
#   -0.4],
#  [u'percentage changes on the same period of the previous year',
#   u'H11 - new dwellings',
#   u'Q1-2014',
#   -2.9],
#  [u'index number', u'H12 - existing dwellings', u'Q1-2014', 84.6],
#  [u'percentage changes on the previous period',
#   u'H12 - existing dwellings',
#   u'Q1-2014',
#   -1.3],
#  [u'percentage changes on the same period of the previous year',
#   u'H12 - existing dwellings',
#   u'Q1-2014',
#   -5.8],
#  [u'index number', u'H1 - all items', u'Q2-2014', 88.7],
#  [u'percentage changes on the previous period',
#   u'H1 - all items',
#   u'Q2-2014',
#   -0.7],
#  [u'percentage changes on the same period of the previous year',
#   u'H1 - all items',
#   u'Q2-2014',
#   -4.9],
#  [u'index number', u'H11 - new dwellings', u'Q2-2014', 100.1],
#  [u'percentage changes on the previous period',
#   u'H11 - new dwellings',
#   u'Q2-2014',
#   -0.4],
#  [u'percentage changes on the same period of the previous year',
#   u'H11 - new dwellings',
#   u'Q2-2014',
#   -2.9],
#  [u'index number', u'H12 - existing dwellings', u'Q2-2014', 83.9],
#  [u'percentage changes on the previous period',
#   u'H12 - existing dwellings',
#   u'Q2-2014',
#   -0.8],
#  [u'percentage changes on the same period of the previous year',
#   u'H12 - existing dwellings',
#   u'Q2-2014',
#   -5.8],
#  [u'index number', u'H1 - all items', u'Q3-2014', 88.3],
#  [u'percentage changes on the previous period',
#   u'H1 - all items',
#   u'Q3-2014',
#   -0.5],
#  [u'percentage changes on the same period of the previous year',
#   u'H1 - all items',
#   u'Q3-2014',
#   -3.9],
#  [u'index number', u'H11 - new dwellings', u'Q3-2014', 100.4],
#  [u'percentage changes on the previous period',
#   u'H11 - new dwellings',
#   u'Q3-2014',
#   0.3],
#  [u'percentage changes on the same period of the previous year',
#   u'H11 - new dwellings',
#   u'Q3-2014',
#   -1.7],
#  [u'index number', u'H12 - existing dwellings', u'Q3-2014', 83.4],
#  [u'percentage changes on the previous period',
#   u'H12 - existing dwellings',
#   u'Q3-2014',
#   -0.6],
#  [u'percentage changes on the same period of the previous year',
#   u'H12 - existing dwellings',
#   u'Q3-2014',
#   -4.7],
#  [u'index number', u'H1 - all items', u'Q4-2014', 86.9],
#  [u'percentage changes on the previous period',
#   u'H1 - all items',
#   u'Q4-2014',
#   -1.6],
#  [u'percentage changes on the same period of the previous year',
#   u'H1 - all items',
#   u'Q4-2014',
#   -3.7],
#  [u'index number', u'H11 - new dwellings', u'Q4-2014', 99.5],
#  [u'percentage changes on the previous period',
#   u'H11 - new dwellings',
#   u'Q4-2014',
#   -0.9],
#  [u'percentage changes on the same period of the previous year',
#   u'H11 - new dwellings',
#   u'Q4-2014',
#   -1.4],
#  [u'index number', u'H12 - existing dwellings', u'Q4-2014', 81.8],
#  [u'percentage changes on the previous period',
#   u'H12 - existing dwellings',
#   u'Q4-2014',
#   -1.9],
#  [u'percentage changes on the same period of the previous year',
#   u'H12 - existing dwellings',
#   u'Q4-2014',
#   -4.6],
#  [u'index number', u'H1 - all items', u'Q1-2015', 86.1],
#  [u'percentage changes on the previous period',
#   u'H1 - all items',
#   u'Q1-2015',
#   -0.9],
#  [u'percentage changes on the same period of the previous year',
#   u'H1 - all items',
#   u'Q1-2015',
#   -3.6],
#  [u'index number', u'H11 - new dwellings', u'Q1-2015', 98.4],
#  [u'percentage changes on the previous period',
#   u'H11 - new dwellings',
#   u'Q1-2015',
#   -1.1],
#  [u'percentage changes on the same period of the previous year',
#   u'H11 - new dwellings',
#   u'Q1-2015',
#   -2.1],
#  [u'index number', u'H12 - existing dwellings', u'Q1-2015', 81.1],
#  [u'percentage changes on the previous period',
#   u'H12 - existing dwellings',
#   u'Q1-2015',
#   -0.9],
#  [u'percentage changes on the same period of the previous year',
#   u'H12 - existing dwellings',
#   u'Q1-2015',
#   -4.1],
#  [u'index number', u'H1 - all items', u'Q2-2015', 86.1],
#  [u'percentage changes on the previous period',
#   u'H1 - all items',
#   u'Q2-2015',
#   None],
#  [u'percentage changes on the same period of the previous year',
#   u'H1 - all items',
#   u'Q2-2015',
#   -2.9],
#  [u'index number', u'H11 - new dwellings', u'Q2-2015', 98.5],
#  [u'percentage changes on the previous period',
#   u'H11 - new dwellings',
#   u'Q2-2015',
#   0.1],
#  [u'percentage changes on the same period of the previous year',
#   u'H11 - new dwellings',
#   u'Q2-2015',
#   -1.6],
#  [u'index number', u'H12 - existing dwellings', u'Q2-2015', 81.1],
#  [u'percentage changes on the previous period',
#   u'H12 - existing dwellings',
#   u'Q2-2015',
#   None],
#  [u'percentage changes on the same period of the previous year',
#   u'H12 - existing dwellings',
#   u'Q2-2015',
#   -3.3],
#  [u'index number', u'H1 - all items', u'Q3-2015', 86.3],
#  [u'percentage changes on the previous period',
#   u'H1 - all items',
#   u'Q3-2015',
#   0.2],
#  [u'percentage changes on the same period of the previous year',
#   u'H1 - all items',
#   u'Q3-2015',
#   -2.3],
#  [u'index number', u'H11 - new dwellings', u'Q3-2015', 99.9],
#  [u'percentage changes on the previous period',
#   u'H11 - new dwellings',
#   u'Q3-2015',
#   1.4],
#  [u'percentage changes on the same period of the previous year',
#   u'H11 - new dwellings',
#   u'Q3-2015',
#   -0.5],
#  [u'index number', u'H12 - existing dwellings', u'Q3-2015', 81],
#  [u'percentage changes on the previous period',
#   u'H12 - existing dwellings',
#   u'Q3-2015',
#   -0.1],
#  [u'percentage changes on the same period of the previous year',
#   u'H12 - existing dwellings',
#   u'Q3-2015',
#   -2.9]]
